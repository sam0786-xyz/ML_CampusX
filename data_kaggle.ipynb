# %%
# This is how we use dataset from Kaggle
# !mkdir -p ~/.kaggle/
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d rishgeeky/indian-pharmaceutical-products -p data/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rishgeeky/indian-pharmaceutical-products
# License(s): MIT
# ...
#   0%|                                               | 0.00/10.5M [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 10.5M/10.5M [00:00<00:00, 2.53GB/s]

# %%
import zipfile
zip_file_path = 'data/indian-pharmaceutical-products.zip'
extract_path = 'data/'
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import pandas as pd
df=pd.read_csv('data/indian_pharmaceutical_products_clean.csv')

# %%
df.sample(5)
# Out:
#         product_id                          brand_name  \
# 183715      183716       Qceph Clav 200mg/125mg Tablet
# 72454        72455                   Efnocar 40 Tablet
# 239877      239878                   Vivotel-CT Tablet
# 15981        15982  Aceton MR 100mg/325mg/250mg Tablet
# 189955      189956               Roxirite 150mg Tablet
#
#                        manufacturer  price_inr  is_discontinued dosage_form  \
# 183715   Emcure Pharmaceuticals Ltd     186.33            False      tablet
# 72454       Zuventus Healthcare Ltd     131.85            False      tablet
# 239877       Rekin Pharma Pvt. Ltd.     120.00            False      tablet
# 15981       Crompton Pharma Pvt Ltd      84.00            False      tablet
# 189955  MHS Pharmaceuticals Pvt Ltd      73.50            False      tablet
#
#         pack_size pack_unit  num_active_ingredients primary_ingredient  \
# 183715        6.0     strip                       2           Cefixime
# ...
